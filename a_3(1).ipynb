# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika-p/assignment-3/blob/master/a_3(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv('/content/mobile_cleaned-1549119762886.csv')
d.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
d.isnull().sum().sum()
# Out:
# 10

# %%
d['weight']=d['weight'].fillna(d['weight'].mean())

# %%
d.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
d.isnull().sum().sum()
# Out:
# 0

# %%
d.describe()
# Out:
#          sim_type    aperture  ...  processor_rank    is_liked
# count  109.000000  109.000000  ...      109.000000  109.000000
# mean     0.981651    7.733945  ...       50.788991    0.844037
# std      1.347025    3.201973  ...       49.496366    0.364496
# min      0.000000    0.000000  ...        1.000000    0.000000
# 25%      0.000000    8.000000  ...       12.000000    1.000000
# 50%      0.000000    8.000000  ...       21.000000    1.000000
# 75%      3.000000   10.000000  ...       92.000000    1.000000
# max      4.000000   14.000000  ...      166.000000    1.000000
#
# [8 rows x 40 columns]
